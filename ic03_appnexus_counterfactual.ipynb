# %%
# build a dataframe 

import pandas as pd

df = pd.read_csv("/Users/orioldiaz/Downloads/counterfactual_appnexus_raw_longer.csv")

# %%
df.tail(2)
# Out:
#           date  adform bCPMM  adyoulike bCPMM  amx bCPMM  beeswax bCPMM  \
# 83  23/11/2024          24.1            215.1       65.5          257.0
# 84  24/11/2024          24.6            174.5       58.1          212.2
#
#     bidswitch bCPMM  conversant bCPMM  criteo bCPMM  gumgum bCPMM  \
# 83            172.5               9.3         323.8         433.7
# 84            185.5              10.4         331.7         437.2
#
#     improvedigital bCPMM  ...  smart bCPMM  sovrn bCPMM  sovrnxsp bCPMM  \
# 83                  87.9  ...        104.7         84.4            17.3
# 84                  99.7  ...        110.2         79.5            20.2
#
#     triplelift bCPMM  ttd bCPMM  undertone bCPMM  unruly bCPMM  \
# 83             183.2       23.9            261.3           5.5
# 84             199.5       29.6            210.3           7.7
#
#     yahoossp bCPMM  yieldmo bCPMM  ic03_dsps_bcpmm
# 83            28.8           62.0            176.4
# 84            23.0           66.9            185.9
#
# [2 rows x 31 columns]

# %%
# rename venatus as test and place it at the end of the dataframe 

df = df.rename(columns={'ic03_dsps_bcpmm': 'test'})

# Reorder the columns to place 'test' at the end
cols = [col for col in df.columns if col != 'test'] + ['test']

# Reindex the dataframe with the new column order
df = df[cols]

# Display the updated dataframe
df.head(2)
# Out:
#          date  adform bCPMM  adyoulike bCPMM  amx bCPMM  beeswax bCPMM  \
# 0  01/09/2024          26.8            317.6       64.3           72.4
# 1  02/09/2024          26.6            259.4       58.7           67.3
#
#    bidswitch bCPMM  conversant bCPMM  criteo bCPMM  gumgum bCPMM  \
# 0             49.3               4.4         240.9         349.8
# 1             39.6               5.2         214.6         322.1
#
#    improvedigital bCPMM  ...  smart bCPMM  sovrn bCPMM  sovrnxsp bCPMM  \
# 0                 150.0  ...         48.4         73.8             0.0
# 1                 153.3  ...         46.6         73.1             0.0
#
#    triplelift bCPMM  ttd bCPMM  undertone bCPMM  unruly bCPMM  yahoossp bCPMM  \
# 0             198.5       30.2            147.3          44.3            44.9
# 1             187.7       31.5            176.3          43.5            44.5
#
#    yieldmo bCPMM   test
# 0           54.4  181.6
# 1           56.9  161.9
#
# [2 rows x 31 columns]

# %% [markdown]
# # Run the counterfactual

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import sklearn.linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
import datetime as dt

# %%
df_display = df

# %%
# rename date column 

df_display = df.rename(columns={'date':'dt'})

#change date field to datetime 

df_display['dt'] = pd.to_datetime(df_display['dt'], format='%d/%m/%Y')

# Remove columns (series) where at least one value is null

df_display = df_display.dropna(axis=1, how='any')

# Sort df_display by 'dt' column in ascending order
df_display = df_display.sort_values(by='dt', ascending=True)

# reset index 

df_display = df_display.reset_index(drop=True)

# %%
df_display.tail(2)
# Out:
#            dt  adform bCPMM  adyoulike bCPMM  amx bCPMM  beeswax bCPMM  \
# 83 2024-11-23          24.1            215.1       65.5          257.0
# 84 2024-11-24          24.6            174.5       58.1          212.2
#
#     bidswitch bCPMM  conversant bCPMM  criteo bCPMM  gumgum bCPMM  \
# 83            172.5               9.3         323.8         433.7
# 84            185.5              10.4         331.7         437.2
#
#     improvedigital bCPMM  ...  sharethrough bCPMM  smart bCPMM  sovrn bCPMM  \
# 83                  87.9  ...               113.4        104.7         84.4
# 84                  99.7  ...               119.1        110.2         79.5
#
#     triplelift bCPMM  ttd bCPMM  undertone bCPMM  unruly bCPMM  \
# 83             183.2       23.9            261.3           5.5
# 84             199.5       29.6            210.3           7.7
#
#     yahoossp bCPMM  yieldmo bCPMM   test
# 83            28.8           62.0  176.4
# 84            23.0           66.9  185.9
#
# [2 rows x 30 columns]

# %%
df_display.head(2)
# Out:
#           dt  adform bCPMM  adyoulike bCPMM  amx bCPMM  beeswax bCPMM  \
# 0 2024-09-01          26.8            317.6       64.3           72.4
# 1 2024-09-02          26.6            259.4       58.7           67.3
#
#    bidswitch bCPMM  conversant bCPMM  criteo bCPMM  gumgum bCPMM  \
# 0             49.3               4.4         240.9         349.8
# 1             39.6               5.2         214.6         322.1
#
#    improvedigital bCPMM  ...  sharethrough bCPMM  smart bCPMM  sovrn bCPMM  \
# 0                 150.0  ...               142.8         48.4         73.8
# 1                 153.3  ...               140.2         46.6         73.1
#
#    triplelift bCPMM  ttd bCPMM  undertone bCPMM  unruly bCPMM  yahoossp bCPMM  \
# 0             198.5       30.2            147.3          44.3            44.9
# 1             187.7       31.5            176.3          43.5            44.5
#
#    yieldmo bCPMM   test
# 0           54.4  181.6
# 1           56.9  161.9
#
# [2 rows x 30 columns]

# %% [markdown]
# # Run regression with stepwise feature selection

# %%
predictors = df_display.columns.to_list()

predictors = predictors[1:-1]

predictors
# Out:
# ['adform bCPMM',
#  'adyoulike bCPMM',
#  'amx bCPMM',
#  'beeswax bCPMM',
#  'bidswitch bCPMM',
#  'conversant bCPMM',
#  'criteo bCPMM',
#  'gumgum bCPMM',
#  'improvedigital bCPMM',
#  'ix bCPMM',
#  'kargo bCPMM',
#  'medianet bCPMM',
#  'nextmillennium bCPMM',
#  'onetag bCPMM',
#  'outbrain bCPMM',
#  'richaudience bCPMM',
#  'rise bCPMM',
#  'rtbhouse bCPMM',
#  'rubicon bCPMM',
#  'sharethrough bCPMM',
#  'smart bCPMM',
#  'sovrn bCPMM',
#  'triplelift bCPMM',
#  'ttd bCPMM',
#  'undertone bCPMM',
#  'unruly bCPMM',
#  'yahoossp bCPMM',
#  'yieldmo bCPMM']

# %%
#use stepwise for variable selection 
#from here https://towardsdatascience.com/stepwise-regression-tutorial-in-python-ebf7c782c922

x_columns = predictors

test_placement = 'test'

y = df_display[test_placement]

# %%
# creating function to get model statistics

import statsmodels.api as sm

def get_stats(x_columns):
    x = df_display[x_columns]
    results = sm.OLS(y, x).fit()
    return results

# Define the significance threshold
alpha = 0.10

# Continue until all p-values are less than alpha
while True:
    # Get regression results
    results = get_stats(x_columns)

    # Get p-values
    p_values = results.pvalues

    # If the max p-value is greater than alpha, remove the corresponding predictor
    if p_values.max() > alpha:
        remove = p_values.idxmax()
        x_columns.remove(remove)
        print(f"Removed: {remove} due to high p-value")
    else:
        # End the loop if all p-values are below the threshold
        break

# Now x_columns contains only the predictors with p-values below alpha
print(results.summary())
# Out:
# Removed: gumgum bCPMM due to high p-value
# Removed: conversant bCPMM due to high p-value
# Removed: outbrain bCPMM due to high p-value
# Removed: criteo bCPMM due to high p-value
# Removed: sharethrough bCPMM due to high p-value
# Removed: nextmillennium bCPMM due to high p-value
# Removed: rise bCPMM due to high p-value
# Removed: amx bCPMM due to high p-value
# Removed: onetag bCPMM due to high p-value
# Removed: undertone bCPMM due to high p-value
# Removed: yieldmo bCPMM due to high p-value
# Removed: adform bCPMM due to high p-value
# Removed: ix bCPMM due to high p-value
# Removed: kargo bCPMM due to high p-value
# Removed: smart bCPMM due to high p-value
# Removed: bidswitch bCPMM due to high p-value
# Removed: improvedigital bCPMM due to high p-value
# Removed: triplelift bCPMM due to high p-value
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   test   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                              4445.
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):                    1.04e-99
# Time:                        15:42:35   Log-Likelihood:                         -288.47
# No. Observations:                  85   AIC:                                      596.9
# Df Residuals:                      75   BIC:                                      621.4
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# adyoulike bCPMM        0.0644      0.020      3.142      0.002       0.024       0.105
# beeswax bCPMM          0.0829      0.026      3.243      0.002       0.032       0.134
# medianet bCPMM        -1.0235      0.151     -6.781      0.000      -1.324      -0.723
# richaudience bCPMM    -9.1410      5.021     -1.821      0.073     -19.143       0.861
# rtbhouse bCPMM         0.1439      0.080      1.790      0.077      -0.016       0.304
# rubicon bCPMM          0.4754      0.046     10.346      0.000       0.384       0.567
# sovrn bCPMM            0.5619      0.108      5.206      0.000       0.347       0.777
# ttd bCPMM              0.5700      0.095      6.026      0.000       0.382       0.758
# unruly bCPMM           0.2742      0.125      2.202      0.031       0.026       0.522
# yahoossp bCPMM         0.4736      0.111      4.260      0.000       0.252       0.695
# ==============================================================================
# Omnibus:                        0.548   Durbin-Watson:                   1.534
# Prob(Omnibus):                  0.760   Jarque-Bera (JB):                0.623
# Skew:                           0.182   Prob(JB):                        0.733
# Kurtosis:                       2.790   Cond. No.                     2.10e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# view predictors 

x_columns
# Out:
# ['adyoulike bCPMM',
#  'beeswax bCPMM',
#  'medianet bCPMM',
#  'richaudience bCPMM',
#  'rtbhouse bCPMM',
#  'rubicon bCPMM',
#  'sovrn bCPMM',
#  'ttd bCPMM',
#  'unruly bCPMM',
#  'yahoossp bCPMM']

# %% [markdown]
# # Train the model with the predictors left

# %%
#split data into test and train (days after the test start become test)

# select first n rows using iloc

idx_2 = df_display.loc[df_display['dt'] == '2024-11-12'].index[0]

df_train = df_display.iloc[:idx_2,:]

# %%
df_train.tail(2)
# Out:
#            dt  adform bCPMM  adyoulike bCPMM  amx bCPMM  beeswax bCPMM  \
# 70 2024-11-10          14.9            290.9       27.3          162.8
# 71 2024-11-11          16.7            241.5       23.4          139.1
#
#     bidswitch bCPMM  conversant bCPMM  criteo bCPMM  gumgum bCPMM  \
# 70            169.2               5.8         260.0         318.0
# 71            156.4               6.0         257.8         211.9
#
#     improvedigital bCPMM  ...  sharethrough bCPMM  smart bCPMM  sovrn bCPMM  \
# 70                 128.3  ...                66.1         64.7         77.4
# 71                  87.1  ...                59.7         60.3         73.9
#
#     triplelift bCPMM  ttd bCPMM  undertone bCPMM  unruly bCPMM  \
# 70             139.9       32.4              1.3           8.5
# 71             137.7       32.5              3.5           6.9
#
#     yahoossp bCPMM  yieldmo bCPMM   test
# 70            30.9          101.5  174.6
# 71            25.8           94.1  158.0
#
# [2 rows x 30 columns]

# %%
df_train.head(2)
# Out:
#           dt  adform bCPMM  adyoulike bCPMM  amx bCPMM  beeswax bCPMM  \
# 0 2024-09-01          26.8            317.6       64.3           72.4
# 1 2024-09-02          26.6            259.4       58.7           67.3
#
#    bidswitch bCPMM  conversant bCPMM  criteo bCPMM  gumgum bCPMM  \
# 0             49.3               4.4         240.9         349.8
# 1             39.6               5.2         214.6         322.1
#
#    improvedigital bCPMM  ...  sharethrough bCPMM  smart bCPMM  sovrn bCPMM  \
# 0                 150.0  ...               142.8         48.4         73.8
# 1                 153.3  ...               140.2         46.6         73.1
#
#    triplelift bCPMM  ttd bCPMM  undertone bCPMM  unruly bCPMM  yahoossp bCPMM  \
# 0             198.5       30.2            147.3          44.3            44.9
# 1             187.7       31.5            176.3          43.5            44.5
#
#    yieldmo bCPMM   test
# 0           54.4  181.6
# 1           56.9  161.9
#
# [2 rows x 30 columns]

# %%
# fit regression 

poly = PolynomialFeatures(degree = 1)
X_train = df_train[x_columns]
X_poly = poly.fit_transform(X_train)
y_train = df_train[test_placement]

poly.fit(X_poly, y_train)
lin2 = sklearn.linear_model.LinearRegression()
lin2.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %%
# check the quality of the model

y_pred = lin2.predict(X_poly)

from sklearn.metrics import r2_score

accuracy = r2_score(y_train, y_pred)*100

print(accuracy)
# Out:
# 83.49802174740279

# %%
# check impact of the test

X_total = df_display[x_columns]

X_total_poly = poly.fit_transform(X_total)

y_total = df_display[test_placement]

y_total_pred = lin2.predict(X_total_poly)

# %%
# converting the NumPy array 
# to a Pandas series

y_total_pred = pd.Series(y_total_pred)

# %%
#create df for comparison

index_labels = df_display['dt'].tolist()

# Assign Index to Series

y_total.index = index_labels
y_total_pred.index = index_labels

# Concat Series by Changing Names
df_predictions=pd.concat({'Test rCPM': y_total,
              'Counterfactual rCPM': y_total_pred}, axis=1)

# %%
# plot predictions 

fig, ax = plt.subplots(figsize=(20,10))

fig.suptitle("IC03 launch for Appnexus", fontsize=20)

x = df_predictions.index

labels = ['Test eCPMs', 'Counterfactual eCPMs', 'IC03 start date 12/11']

ax.plot(x, df_predictions['Test rCPM'], color='blue')
ax.plot(x, df_predictions['Counterfactual rCPM'], color='red')
ax.axvline(dt.datetime(2024, 11, 8), color = 'pink', linestyle = '--', linewidth = 4)
ax.set_ylabel('bCPMM ($)')
ax.set_xlabel('Date')
ax.set_title('Test includes bCPMM appnexus', size=15)
ax.legend(labels, loc='best')
ax.grid(True)

# %%
df_predictions.tail(5)
# Out:
#             Test rCPM  Counterfactual rCPM
# 2024-11-20      168.0           159.581747
# 2024-11-21      177.6           184.190073
# 2024-11-22      190.4           181.851164
# 2024-11-23      176.4           182.476656
# 2024-11-24      185.9           183.049468

# %%
df_predictions.to_csv('df_predictions_ic03_appnexus.csv')

# %%
# coefficients and intercept 

cdf = pd.DataFrame(lin2.coef_, columns=['Coefficients'])

coefs = pd.DataFrame(
    lin2.coef_[1:],
    columns=["Coefficients"],
    index=X_train.columns,
)

# Rank the coefficients from highest to lowest
coefs = coefs.sort_values(by="Coefficients", ascending=False)

coefs
# Out:
#                     Coefficients
# ttd bCPMM               0.530014
# yahoossp bCPMM          0.485928
# sovrn bCPMM             0.465649
# rubicon bCPMM           0.455438
# unruly bCPMM            0.222314
# rtbhouse bCPMM          0.102940
# beeswax bCPMM           0.079394
# adyoulike bCPMM         0.050243
# medianet bCPMM         -0.958241
# richaudience bCPMM    -11.818845

# %%
#coefs.to_csv('coefs.csv')

# %%
intercept = lin2.intercept_

print("Intercept = "+"{:.4f}".format(intercept))
# Out:
# Intercept = 15.7197
